# %% [markdown]
# Import Libraries

# %%
import numpy as np 
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

# %% [markdown]
# Read Data

# %%
df_train = pd.read_csv("1991_stats.csv", delimiter=",")
df_train[0:5]
# Out:
#    Rk                     Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 0   1    Chris Mullin*\mullich01  SF   27  GSW  82  82  40.4   9.5  17.7  ...
# 1   2     Karl Malone*\malonka01  PF   27  UTA  82  82  40.3  10.3  19.6  ...
# 2   3  Mitch Richmond*\richmmi01  SG   25  GSW  77  77  39.3   9.1  18.5  ...
# 3   4     Tim Hardaway\hardati01  PG   24  GSW  82  82  39.2   9.0  18.9  ...
# 4   5    Tyrone Corbin\corbity01  SF   28  MIN  82  82  39.0   7.2  16.0  ...
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  isAllNBA
# 0  1.7  3.7   5.4  4.0  2.1  0.8  3.0  2.1  25.7         1
# 1  2.9  8.9  11.8  3.3  1.1  1.0  3.0  3.3  29.0         1
# 2  1.9  4.0   5.9  3.1  1.6  0.4  3.0  2.7  23.9         0
# 3  1.1  3.0   4.0  9.7  2.6  0.1  3.3  2.8  22.9         0
# 4  2.3  4.9   7.2  4.2  2.0  0.6  2.5  3.1  18.0         0
#
# [5 rows x 31 columns]

# %%
df_test = pd.read_csv("1992_stats.csv", delimiter=",")
df_test[0:5]
# Out:
#    Rk                    Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 0   1   Chris Mullin*\mullich01  SF   28  GSW  81  81  41.3  10.2  19.6  ...
# 1   2    Tim Hardaway\hardati01  PG   25  GSW  81  81  41.1   9.1  19.7  ...
# 2   3  Dennis Rodman*\rodmade01  PF   30  DET  82  80  40.3   4.2   7.7  ...
# 3   4   James Worthy*\worthja01  SF   30  LAL  54  54  39.0   8.3  18.6  ...
# 4   5     Joe Dumars*\dumarjo01  SG   28  DET  82  82  38.9   7.2  16.0  ...
#
#    ORB   DRB   TRB   AST  STL  BLK  TOV   PF   PTS  isAllNBA
# 0  1.6   4.0   5.6   3.5  2.1  0.8  2.5  2.1  25.6         1
# 1  1.0   2.8   3.8  10.0  2.0  0.2  3.3  2.6  23.4         1
# 2  6.4  12.3  18.7   2.3  0.8  0.9  1.7  3.0   9.8         1
# 3  1.8   3.8   5.6   4.7  1.4  0.4  2.4  1.6  19.9         0
# 4  1.0   1.3   2.3   4.6  0.9  0.1  2.4  1.8  19.9         0
#
# [5 rows x 31 columns]

# %% [markdown]
# Pre-processing

# %%
df_train = df_train.drop(labels=['Rk','Player','Age','Tm','G','GS','MP'],axis=1)
df_train = df_train.fillna(0)
df_train[0:5]
# Out:
#   Pos    FG   FGA    FG%   3P  3PA    3P%    2P   2PA    2P%  ...  ORB  DRB  \
# 0  SF   9.5  17.7  0.536  0.5  1.6  0.301   9.0  16.0  0.560  ...  1.7  3.7
# 1  PF  10.3  19.6  0.527  0.0  0.2  0.286  10.3  19.4  0.529  ...  2.9  8.9
# 2  SG   9.1  18.5  0.494  0.5  1.5  0.348   8.6  17.0  0.506  ...  1.9  4.0
# 3  PG   9.0  18.9  0.476  1.2  3.1  0.385   7.8  15.8  0.494  ...  1.1  3.0
# 4  SF   7.2  16.0  0.448  0.0  0.1  0.200   7.1  15.9  0.450  ...  2.3  4.9
# 5  SG   7.4  15.6  0.472  1.4  3.4  0.400   6.0  12.3  0.491  ...  0.6  3.3
# 6   C   8.0  15.2  0.524  0.0  0.0  0.000   8.0  15.2  0.525  ...  2.3  8.6
# 7  SF   9.2  18.7  0.492  0.3  1.2  0.289   8.8  17.5  0.505  ...  1.4  3.2
# 8  PG   7.7  16.5  0.470  0.5  1.6  0.328   7.2  14.9  0.485  ...  1.0  2.5
# 9   C  10.4  20.3  0.514  0.0  0.1  0.000  10.4  20.2  0.516  ...  2.4  8.8
#
#     TRB  AST  STL  BLK  TOV   PF   PTS  isAllNBA
# 0   5.4  4.0  2.1  0.8  3.0  2.1  25.7         1
# 1  11.8  3.3  1.1  1.0  3.0  3.3  29.0         1
# 2   5.9  3.1  1.6  0.4  3.0  2.7  23.9         0
# 3   4.0  9.7  2.6  0.1  3.3  2.8  22.9         0
# 4   7.2  4.2  2.0  0.6  2.5  3.1  18.0         0
# 5   3.9  3.7  2.2  0.5  2.7  2.3  22.1         0
# 6  10.9  3.3  1.0  0.6  2.8  2.5  21.6         0
# 7   4.6  3.5  1.3  0.4  1.6  1.5  21.4         1
# 8   3.5  9.0  1.6  0.2  2.1  1.4  17.1         0
# 9  11.2  3.0  1.0  3.2  3.6  3.5  26.6         1
#
# [10 rows x 24 columns]

# %%
df_test = df_test.drop(labels=['Rk','Player','Age','Tm','G','GS','MP'],axis=1)
df_test = df_test.fillna(0)
df_test[0:5]
# Out:
#   Pos    FG   FGA    FG%   3P  3PA    3P%   2P   2PA    2P%  ...  ORB   DRB  \
# 0  SF  10.2  19.6  0.524  0.8  2.2  0.366  9.5  17.4  0.544  ...  1.6   4.0
# 1  PG   9.1  19.7  0.461  1.6  4.6  0.338  7.5  15.0  0.499  ...  1.0   2.8
# 2  PF   4.2   7.7  0.539  0.4  1.2  0.317  3.8   6.5  0.581  ...  6.4  12.3
# 3  SF   8.3  18.6  0.447  0.2  0.8  0.209  8.2  17.9  0.457  ...  1.8   3.8
# 4  SG   7.2  16.0  0.448  0.6  1.5  0.408  6.6  14.5  0.452  ...  1.0   1.3
#
#     TRB   AST  STL  BLK  TOV   PF   PTS  isAllNBA
# 0   5.6   3.5  2.1  0.8  2.5  2.1  25.6         1
# 1   3.8  10.0  2.0  0.2  3.3  2.6  23.4         1
# 2  18.7   2.3  0.8  0.9  1.7  3.0   9.8         1
# 3   5.6   4.7  1.4  0.4  2.4  1.6  19.9         0
# 4   2.3   4.6  0.9  0.1  2.4  1.8  19.9         0
#
# [5 rows x 24 columns]

# %%
X_train = df_train[['Pos', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].values
le_pos = preprocessing.LabelEncoder()
le_pos.fit(['PG','SG','SF','PF','C'])
X_train[:,0] = le_pos.transform(X_train[:,0])
X_train[0:5]
# Out:
# array([[3, 9.5, 17.7, 0.536, 0.5, 1.6, 0.301, 9.0, 16.0, 0.56, 0.55, 6.3,
#         7.1, 0.884, 1.7, 3.7, 5.4, 4.0, 2.1, 0.8, 3.0, 2.1, 25.7],
#        [1, 10.3, 19.6, 0.527, 0.0, 0.2, 0.286, 10.3, 19.4, 0.529, 0.528,
#         8.3, 10.8, 0.77, 2.9, 8.9, 11.8, 3.3, 1.1, 1.0, 3.0, 3.3, 29.0],
#        [4, 9.1, 18.5, 0.494, 0.5, 1.5, 0.348, 8.6, 17.0, 0.506, 0.508,
#         5.1, 6.0, 0.847, 1.9, 4.0, 5.9, 3.1, 1.6, 0.4, 3.0, 2.7, 23.9],
#        [2, 9.0, 18.9, 0.476, 1.2, 3.1, 0.385, 7.8, 15.8, 0.494, 0.508,
#         3.7, 4.6, 0.803, 1.1, 3.0, 4.0, 9.7, 2.6, 0.1, 3.3, 2.8, 22.9],
#        [3, 7.2, 16.0, 0.448, 0.0, 0.1, 0.2, 7.1, 15.9, 0.45, 0.449, 3.6,
#         4.5, 0.798, 2.3, 4.9, 7.2, 4.2, 2.0, 0.6, 2.5, 3.1, 18.0]],
#       dtype=object)

# %%
y_train = df_train["isAllNBA"]
y_train [0:5]
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: isAllNBA, dtype: int64

# %%
X_test = df_test[['Pos', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].values
le_pos2 = preprocessing.LabelEncoder()
le_pos2.fit(['PG','SG','SF','PF','C'])
X_test[:,0] = le_pos2.transform(X_test[:,0])
X_test[0:5]
# Out:
# array([[3, 10.2, 19.6, 0.524, 0.8, 2.2, 0.366, 9.5, 17.4, 0.544, 0.544,
#         4.3, 5.2, 0.833, 1.6, 4.0, 5.6, 3.5, 2.1, 0.8, 2.5, 2.1, 25.6],
#        [2, 9.1, 19.7, 0.461, 1.6, 4.6, 0.338, 7.5, 15.0, 0.499, 0.501,
#         3.7, 4.8, 0.766, 1.0, 2.8, 3.8, 10.0, 2.0, 0.2, 3.3, 2.6, 23.4],
#        [1, 4.2, 7.7, 0.539, 0.4, 1.2, 0.317, 3.8, 6.5, 0.581, 0.564, 1.0,
#         1.7, 0.6, 6.4, 12.3, 18.7, 2.3, 0.8, 0.9, 1.7, 3.0, 9.8],
#        [3, 8.3, 18.6, 0.447, 0.2, 0.8, 0.209, 8.2, 17.9, 0.457, 0.451,
#         3.1, 3.8, 0.814, 1.8, 3.8, 5.6, 4.7, 1.4, 0.4, 2.4, 1.6, 19.9],
#        [4, 7.2, 16.0, 0.448, 0.6, 1.5, 0.408, 6.6, 14.5, 0.452, 0.466,
#         5.0, 5.8, 0.867, 1.0, 1.3, 2.3, 4.6, 0.9, 0.1, 2.4, 1.8, 19.9]],
#       dtype=object)

# %%
y_test = df_test["isAllNBA"]
y_test [0:5]
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    0
# Name: isAllNBA, dtype: int64

# %% [markdown]
# Modeling

# %%
decTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
decTree # it shows the default parameters
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
decTree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %% [markdown]
# Prediction

# %%
predTree = decTree.predict(X_test)

# %% [markdown]
# Evaluation

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_test, predTree))
# Out:
# DecisionTrees's Accuracy:  0.9533333333333334

# %% [markdown]
# Visualization

# %%
from  io import StringIO
import pydotplus
import matplotlib.image as mpimg
from sklearn import tree
# %matplotlib inline

# %%
dot_data = StringIO()
filename = "dectree.png"
featureNames = df_test.columns[0:23]
out=tree.export_graphviz(decTree,feature_names=featureNames, out_file=dot_data, class_names= ["0","1"], filled=True,  special_characters=True,rotate=False)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png(filename)
img = mpimg.imread(filename)
plt.figure(figsize=(100, 200))
plt.imshow(img,interpolation='nearest')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11356/1557776707.py in <module>
#       2 filename = "dectree.png"
#       3 featureNames = df_test.columns[0:23]
# ----> 4 out=tree.export_graphviz(decTree,feature_names=featureNames, out_file=dot_data, class_names= np.unique(y_train), filled=True,  special_characters=True,rotate=False)
#       5 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
#       6 graph.write_png(filename)
#
# D:\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# D:\anaconda3\lib\site-packages\sklearn\tree\_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     786             rounded=rounded, special_characters=special_characters,
#     787             precision=precision)
# --> 788         exporter.export(decision_tree)
#     789
#     790         if return_string:
#
# D:\anaconda3\lib\site-packages\sklearn\tree\_export.py in export(self, decision_tree)
#     422             self.recurse(decision_tree, 0, criterion="impurity")
#     423         else:
# --> 424             self.recurse(decision_tree.tree_, 0,
#     425                          criterion=decision_tree.criterion)
#     426
#
# D:\anaconda3\lib\site-packages\sklearn\tree\_export.py in recurse(self, tree, node_id, criterion, parent, depth)
#     482
#     483             self.out_file.write(
# --> 484                 '%d [label=%s' % (node_id, self.node_to_str(tree, node_id,
#     485                                                             criterion)))
#     486
#
# D:\anaconda3\lib\site-packages\sklearn\tree\_export.py in node_to_str(self, tree, node_id, criterion)
#     358                                           np.argmax(value),
#     359                                           characters[2])
# --> 360             node_string += class_name
#     361
#     362         # Clean up any trailing newlines
#
# TypeError: can only concatenate str (not "numpy.int64") to str
